# %%
import openai
import os
import dotenv
from dotenv import load_dotenv

# %%
load_dotenv()
api_key = os.getenv("OPENAI_API")
print(api_key)
# Out:
# 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

# %%
import logging
from openai import OpenAI

#configure logging
logging.basicConfig(level=logging.DEBUG)
logger = logging.getLogger(__name__)

client = OpenAI(api_key=api_key)

#define your prompt
prompt = "The ad begins with a suspenseful animation of a LEGO CITY set, with the tagline 'YOUR CITY, NO LIMITS' and a countdown timer."

response = client.images.generate(
    model="dall-e-3",
    prompt=prompt,
    size="1024x1024",
    quality="hd",
    style='vivid',
    n=1,
)

logger.debug("Request Data: %s", response)
# Out:
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/images/generations', 'files': None, 'json_data': {'prompt': "The ad begins with a suspenseful animation of a LEGO CITY set, with the tagline 'YOUR CITY, NO LIMITS' and a countdown timer.", 'model': 'dall-e-3', 'n': 1, 'quality': 'hd', 'size': '1024x1024', 'style': 'vivid'}}
# DEBUG:httpx._client:HTTP Request: POST https://api.openai.com/v1/images/generations "HTTP/1.1 200 OK"
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/images/generations "200 OK"
# DEBUG:__main__:Request Data: ImagesResponse(created=1708210024, data=[Image(b64_json=None, revised_prompt="Begin with a thrilling animation of a generic construction toy city, not branded but resembling a miniature metropolitan area. This cityscape is teeming with playset buildings, roads, and vehicles. It contains the tagline 'YOUR CITY, NO LIMITS' prominently displayed, hinting at endless building possibilities. Additionally, there's a countdown timer, adding to the suspense and anticipating an exciting event.", url='https://oaidalleapiprodscus.blob.core.windows.net/private/org-meifkcFj5A9IjlflOqxcVZBe/user-ZPTxrE5Z3of20YjzdGT5LsFj/img-9gdaI3UJZUWe4flqLC4q9ZJN.png?st=2024-02-17T21%3A47%3A04Z&se=2024-02-17T23%3A47%3A04Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-02-17T02%3A37%3A16Z&ske=2024-02-18T02%3A37%3A16Z&sks=b&skv=2021-08-06&sig=Ze12DDeWgOI77q47OjQlNfoiDI8MKvfCEmFdD23jLOw%3D')])

# %%
image_url = response.data[0].url
image_url
# Out:
# 'https://oaidalleapiprodscus.blob.core.windows.net/private/org-meifkcFj5A9IjlflOqxcVZBe/user-ZPTxrE5Z3of20YjzdGT5LsFj/img-9gdaI3UJZUWe4flqLC4q9ZJN.png?st=2024-02-17T21%3A47%3A04Z&se=2024-02-17T23%3A47%3A04Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-02-17T02%3A37%3A16Z&ske=2024-02-18T02%3A37%3A16Z&sks=b&skv=2021-08-06&sig=Ze12DDeWgOI77q47OjQlNfoiDI8MKvfCEmFdD23jLOw%3D'

# %%
import requests
import os

def download_image(url, folder_path):
    # Send a GET request to the URL
    response = requests.get(url)
    
    # Check if the request was successful
    if response.status_code == 200:
        # Extract the filename from the URL
        filename = url.split("/")[-1].split("?")[0] + ".png"
        # Create the folder if it doesn't exist
        if not os.path.exists(folder_path):
            os.makedirs(folder_path)
        # Save the image to the specified folder
        with open(os.path.join(folder_path, filename), 'wb') as f:
            f.write(response.content)
        print(f"Image downloaded successfully at {os.path.join(folder_path, filename)}")
    else:
        print("Failed to download image")

# Example usage
url = image_url
folder_path = "/home/biniyam/TenAcademy/StoryBoard-Generation/images"
download_image(url, folder_path)
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): oaidalleapiprodscus.blob.core.windows.net:443
# DEBUG:urllib3.connectionpool:https://oaidalleapiprodscus.blob.core.windows.net:443 "GET /private/org-meifkcFj5A9IjlflOqxcVZBe/user-ZPTxrE5Z3of20YjzdGT5LsFj/img-9gdaI3UJZUWe4flqLC4q9ZJN.png?st=2024-02-17T21%3A47%3A04Z&se=2024-02-17T23%3A47%3A04Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-02-17T02%3A37%3A16Z&ske=2024-02-18T02%3A37%3A16Z&sks=b&skv=2021-08-06&sig=Ze12DDeWgOI77q47OjQlNfoiDI8MKvfCEmFdD23jLOw%3D HTTP/1.1" 200 3162696
# Image downloaded successfully at /home/biniyam/TenAcademy/StoryBoard-Generation/images/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-02-17T02%3A37%3A16Z&ske=2024-02-18T02%3A37%3A16Z&sks=b&skv=2021-08-06&sig=Ze12DDeWgOI77q47OjQlNfoiDI8MKvfCEmFdD23jLOw%3D.png

# %%
frame_prompts = [
    "A collage of various travel experiences, meticulously crafted with high-resolution images showcasing diverse destinations and activities - from backpacking in the Himalayas, to luxury cruises in the Mediterranean, to cultural tours in South America. The text 'Your Travel, Your Way' appears in bold, sophisticated typography, overlaying the collage, encapsulating the brand's personalized approach. The Inspiring Travel logo is subtly placed in the top right corner to reinforce brand recognition.",
    "A first-person view of the diverse range of travel experiences offered by Inspiring Travel, immersing users in the world of exploration and adventure. Each image represents a unique travel experience - a private safari tour, a culinary journey in Italy, a historical exploration in Egypt. A soothing, confident voice of a Travel Specialist provides a voiceover detailing the customization options available, enhancing the immersive experience. Swipe functionality allows users to navigate through the images at their own pace, reinforcing the 'Your Travel, Your Way' message.",
    "A captivating image of a world map, symbolizing the endless possibilities with Inspiring Travel. A prominent 'Start Your Journey' button, designed to prompt viewer interaction and response, is placed centrally on the world map. The Inspiring Travel logo is subtly placed in the top right corner to reinforce brand recognition.",
    "A series of images showcasing the diverse range of travel experiences offered by Inspiring Travel, with each image representing a unique destination or activity. A voiceover by a Travel Specialist details the customization options available, enhancing the immersive experience. Swipe functionality allows users to navigate through the images, reinforcing the 'Your Travel, Your Way' message.",
    "An immersive video montage showcasing various travel experiences offered by Inspiring Travel - from breathtaking landscapes to cultural festivals. A warm, engaging voice of a Travel Specialist provides a voiceover, detailing the customization options available. Swipe functionality allows users to navigate through the video at their own pace, reinforcing the brand's personalized approach.",
    "A stunning image of a globe, symbolizing the endless possibilities with Inspiring Travel. A prominent 'Start Your Journey' button, designed to prompt viewer interaction and response, is placed centrally on the globe. The Inspiring Travel logo is subtly placed in the top right corner to reinforce brand recognition."
]

from openai import OpenAI
client = OpenAI(api_key=api_key)

for prompt in frame_prompts:
    response = client.images.generate(
        model="dall-e-3",
        prompt=prompt,
        quality="hd",
        n=1,
        size="1024x1024",
        style="vivid"
    )
    download_image(response.data[0].url, folder_path="/home/biniyam/TenAcademy/StoryBoard-Generation/images")
# Out:
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/images/generations', 'files': None, 'json_data': {'prompt': "A collage of various travel experiences, meticulously crafted with high-resolution images showcasing diverse destinations and activities - from backpacking in the Himalayas, to luxury cruises in the Mediterranean, to cultural tours in South America. The text 'Your Travel, Your Way' appears in bold, sophisticated typography, overlaying the collage, encapsulating the brand's personalized approach. The Inspiring Travel logo is subtly placed in the top right corner to reinforce brand recognition.", 'model': 'dall-e-3', 'n': 1, 'quality': 'hd', 'size': '1024x1024', 'style': 'vivid'}}
# DEBUG:httpx._client:HTTP Request: POST https://api.openai.com/v1/images/generations "HTTP/1.1 200 OK"
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/images/generations "200 OK"
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): oaidalleapiprodscus.blob.core.windows.net:443
# DEBUG:urllib3.connectionpool:https://oaidalleapiprodscus.blob.core.windows.net:443 "GET /private/org-meifkcFj5A9IjlflOqxcVZBe/user-ZPTxrE5Z3of20YjzdGT5LsFj/img-LBvIHV5eukxNylzt9mmyca6L.png?st=2024-02-17T22%3A35%3A06Z&se=2024-02-18T00%3A35%3A06Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-02-17T17%3A06%3A22Z&ske=2024-02-18T17%3A06%3A22Z&sks=b&skv=2021-08-06&sig=0DCVsIoGJ2jpFhE9ZO7beR6ORU2g%2BEfHe8GhgPu30WA%3D HTTP/1.1" 200 3162696
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/images/generations', 'files': None, 'json_data': {'prompt': "A first-person view of the diverse range of travel experiences offered by Inspiring Travel, immersing users in the world of exploration and adventure. Each image represents a unique travel experience - a private safari tour, a culinary journey in Italy, a historical exploration in Egypt. A soothing, confident voice of a Travel Specialist provides a voiceover detailing the customization options available, enhancing the immersive experience. Swipe functionality allows users to navigate through the images at their own pace, reinforcing the 'Your Travel, Your Way' message.", 'model': 'dall-e-3', 'n': 1, 'quality': 'hd', 'size': '1024x1024', 'style': 'vivid'}}
# Image downloaded successfully at /home/biniyam/TenAcademy/StoryBoard-Generation/images/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-02-17T17%3A06%3A22Z&ske=2024-02-18T17%3A06%3A22Z&sks=b&skv=2021-08-06&sig=0DCVsIoGJ2jpFhE9ZO7beR6ORU2g%2BEfHe8GhgPu30WA%3D.png
# DEBUG:httpx._client:HTTP Request: POST https://api.openai.com/v1/images/generations "HTTP/1.1 200 OK"
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/images/generations "200 OK"
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): oaidalleapiprodscus.blob.core.windows.net:443
# DEBUG:urllib3.connectionpool:https://oaidalleapiprodscus.blob.core.windows.net:443 "GET /private/org-meifkcFj5A9IjlflOqxcVZBe/user-ZPTxrE5Z3of20YjzdGT5LsFj/img-6P1dk0GUHXH5FHPCNXPnneGA.png?st=2024-02-17T22%3A35%3A29Z&se=2024-02-18T00%3A35%3A29Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-02-17T16%3A35%3A14Z&ske=2024-02-18T16%3A35%3A14Z&sks=b&skv=2021-08-06&sig=pQ%2BdEgnOXIPHs%2BqhQidF5Jy9TPJ6wq3oAEE29cPlCIQ%3D HTTP/1.1" 200 3162696
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/images/generations', 'files': None, 'json_data': {'prompt': "A captivating image of a world map, symbolizing the endless possibilities with Inspiring Travel. A prominent 'Start Your Journey' button, designed to prompt viewer interaction and response, is placed centrally on the world map. The Inspiring Travel logo is subtly placed in the top right corner to reinforce brand recognition.", 'model': 'dall-e-3', 'n': 1, 'quality': 'hd', 'size': '1024x1024', 'style': 'vivid'}}
# Image downloaded successfully at /home/biniyam/TenAcademy/StoryBoard-Generation/images/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-02-17T16%3A35%3A14Z&ske=2024-02-18T16%3A35%3A14Z&sks=b&skv=2021-08-06&sig=pQ%2BdEgnOXIPHs%2BqhQidF5Jy9TPJ6wq3oAEE29cPlCIQ%3D.png
# DEBUG:httpx._client:HTTP Request: POST https://api.openai.com/v1/images/generations "HTTP/1.1 200 OK"
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/images/generations "200 OK"
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): oaidalleapiprodscus.blob.core.windows.net:443
# DEBUG:urllib3.connectionpool:https://oaidalleapiprodscus.blob.core.windows.net:443 "GET /private/org-meifkcFj5A9IjlflOqxcVZBe/user-ZPTxrE5Z3of20YjzdGT5LsFj/img-1KMvI6glespmwPwjhoDZIc2U.png?st=2024-02-17T22%3A35%3A49Z&se=2024-02-18T00%3A35%3A49Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-02-17T16%3A22%3A59Z&ske=2024-02-18T16%3A22%3A59Z&sks=b&skv=2021-08-06&sig=2f9pvA6MliLJLSwRGmu8h1CXi146/KHry7B0DK9wK2g%3D HTTP/1.1" 200 3162696
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/images/generations', 'files': None, 'json_data': {'prompt': "A series of images showcasing the diverse range of travel experiences offered by Inspiring Travel, with each image representing a unique destination or activity. A voiceover by a Travel Specialist details the customization options available, enhancing the immersive experience. Swipe functionality allows users to navigate through the images, reinforcing the 'Your Travel, Your Way' message.", 'model': 'dall-e-3', 'n': 1, 'quality': 'hd', 'size': '1024x1024', 'style': 'vivid'}}
# Image downloaded successfully at /home/biniyam/TenAcademy/StoryBoard-Generation/images/KHry7B0DK9wK2g%3D.png
# DEBUG:httpx._client:HTTP Request: POST https://api.openai.com/v1/images/generations "HTTP/1.1 200 OK"
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/images/generations "200 OK"
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): oaidalleapiprodscus.blob.core.windows.net:443
# DEBUG:urllib3.connectionpool:https://oaidalleapiprodscus.blob.core.windows.net:443 "GET /private/org-meifkcFj5A9IjlflOqxcVZBe/user-ZPTxrE5Z3of20YjzdGT5LsFj/img-j9VAPb7jOf27YTm9oDhwOakc.png?st=2024-02-17T22%3A36%3A11Z&se=2024-02-18T00%3A36%3A11Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-02-17T19%3A32%3A13Z&ske=2024-02-18T19%3A32%3A13Z&sks=b&skv=2021-08-06&sig=nEAz%2Bt%2B5xwdEkHzT1N3upRy4zwB4PBJXoQ7aCO1udnE%3D HTTP/1.1" 200 3162696
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/images/generations', 'files': None, 'json_data': {'prompt': "An immersive video montage showcasing various travel experiences offered by Inspiring Travel - from breathtaking landscapes to cultural festivals. A warm, engaging voice of a Travel Specialist provides a voiceover, detailing the customization options available. Swipe functionality allows users to navigate through the video at their own pace, reinforcing the brand's personalized approach.", 'model': 'dall-e-3', 'n': 1, 'quality': 'hd', 'size': '1024x1024', 'style': 'vivid'}}
# Image downloaded successfully at /home/biniyam/TenAcademy/StoryBoard-Generation/images/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-02-17T19%3A32%3A13Z&ske=2024-02-18T19%3A32%3A13Z&sks=b&skv=2021-08-06&sig=nEAz%2Bt%2B5xwdEkHzT1N3upRy4zwB4PBJXoQ7aCO1udnE%3D.png
# DEBUG:httpx._client:HTTP Request: POST https://api.openai.com/v1/images/generations "HTTP/1.1 200 OK"
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/images/generations "200 OK"
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): oaidalleapiprodscus.blob.core.windows.net:443
# DEBUG:urllib3.connectionpool:https://oaidalleapiprodscus.blob.core.windows.net:443 "GET /private/org-meifkcFj5A9IjlflOqxcVZBe/user-ZPTxrE5Z3of20YjzdGT5LsFj/img-sm063n48XhS9b6iPQRV961R6.png?st=2024-02-17T22%3A36%3A34Z&se=2024-02-18T00%3A36%3A34Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-02-17T22%3A02%3A21Z&ske=2024-02-18T22%3A02%3A21Z&sks=b&skv=2021-08-06&sig=A49H0b7zVI3Yrd/qmX7T1lkkLZv6ylLNtvLYSotOLkk%3D HTTP/1.1" 200 3162696
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/images/generations', 'files': None, 'json_data': {'prompt': "A stunning image of a globe, symbolizing the endless possibilities with Inspiring Travel. A prominent 'Start Your Journey' button, designed to prompt viewer interaction and response, is placed centrally on the globe. The Inspiring Travel logo is subtly placed in the top right corner to reinforce brand recognition.", 'model': 'dall-e-3', 'n': 1, 'quality': 'hd', 'size': '1024x1024', 'style': 'vivid'}}
# Image downloaded successfully at /home/biniyam/TenAcademy/StoryBoard-Generation/images/qmX7T1lkkLZv6ylLNtvLYSotOLkk%3D.png
# DEBUG:httpx._client:HTTP Request: POST https://api.openai.com/v1/images/generations "HTTP/1.1 200 OK"
# DEBUG:openai._base_client:HTTP Request: POST https://api.openai.com/v1/images/generations "200 OK"
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): oaidalleapiprodscus.blob.core.windows.net:443
# DEBUG:urllib3.connectionpool:https://oaidalleapiprodscus.blob.core.windows.net:443 "GET /private/org-meifkcFj5A9IjlflOqxcVZBe/user-ZPTxrE5Z3of20YjzdGT5LsFj/img-JIh9D0gwsPAWZYaYOHFzIf6Q.png?st=2024-02-17T22%3A36%3A55Z&se=2024-02-18T00%3A36%3A55Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-02-17T14%3A57%3A42Z&ske=2024-02-18T14%3A57%3A42Z&sks=b&skv=2021-08-06&sig=hLkPrJdfzEaltZ1I4C0Y74N5PUCKRrXs8vavUIIBG5k%3D HTTP/1.1" 200 3162696
# Image downloaded successfully at /home/biniyam/TenAcademy/StoryBoard-Generation/images/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-02-17T14%3A57%3A42Z&ske=2024-02-18T14%3A57%3A42Z&sks=b&skv=2021-08-06&sig=hLkPrJdfzEaltZ1I4C0Y74N5PUCKRrXs8vavUIIBG5k%3D.png

# %%
#make a storyboard

import cv2
import os
import numpy as np
import random

def resize_images(image, width):
    aspect_ratio = image.shape[1] / image.shape[0]
    height = int(width / aspect_ratio)
    resized_image = cv2.resize(image, (width, height))
    return resized_image

def create_storyboard(image_folder, output_path, storyboard_size=(1024,1024), images_per_row=3):
    images = []
    for img_name in os.listdir(image_folder):
        img_path = os.path.join(image_folder, img_name)
        image = cv2.imread(img_path)
        if image is not None:
            image = resize_images(image, storyboard_size[0] // images_per_row)
            images.append(image)
            
    rows = len(images) // images_per_row
    if len(images) % images_per_row != 0:
        rows += 1
        
    storyboard = np.zeros((storyboard_size[1], storyboard_size[0], 3), dtype=np.uint8)
    
    for i, img in enumerate(images):
        x_offset = (i % images_per_row) * (storyboard_size[0] // images_per_row)
        y_offset = (i // images_per_row) * (storyboard_size[1] // rows)
        
        storyboard[y_offset:y_offset+img.shape[0], x_offset:x_offset+img.shape[1]] = img
        
    cv2.imwrite(output_path, storyboard)
    cv2.imshow("Storyboard", storyboard)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
image_folder = "/home/biniyam/TenAcademy/StoryBoard-Generation/images/lego_city"
output_path = "/home/biniyam/TenAcademy/StoryBoard-Generation/images/lego_city/storyboard.png"
create_storyboard(image_folder, output_path)
# Out:
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
#
# QObject::moveToThread: Current thread (0x1ca7780) is not the object's thread (0x2ef3510).
# Cannot move to target thread (0x1ca7780)
